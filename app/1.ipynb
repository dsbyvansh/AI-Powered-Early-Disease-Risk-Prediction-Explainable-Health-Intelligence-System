# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/x_train_final.csv")

# %%
df["GENHLTH"].value_counts()
# Out:
# GENHLTH
# 1.0    544523
# 2.0    490678
# 0.0    294581
# 3.0    204260
# 4.0     80814
# Name: count, dtype: int64

# %%
df["_CHLDCNT"].max()
# Out:
# 5.0
